# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# Use forward slashes or double backslashes in the file path
df = pd.read_csv("/content/IPL_2023-22_Sold_Players.csv")
df
# Out:
#      Season               Name Nationality          Type  \
# 0      2023    Ajinkya Rahane      Indian        Batter
# 1      2023     Bhagath Varma      Indian   All-Rounder
# 2      2023     Kyle Jamieson    Overseas        Bowler
# 3      2023       Ajay Mandal      Indian   All-Rounder
# 4      2023    Nishant Sindhu      Indian   All-Rounder
# ..      ...                ...         ...           ...
# 279    2022  Fazalhaq Farooqi    Overseas        Bowler
# 280    2022       Sean Abbott    Overseas        Bowler
# 281    2022         R Samarth      Indian       Batsman
# 282    2022    Shashank Singh      Indian   All-Rounder
# 283    2022     Saurabh Dubey      Indian        Bowler
#
#                      Team         Price
# 0     Chennai Super Kings    50,00,000
# 1     Chennai Super Kings    20,00,000
# 2     Chennai Super Kings  1,00,00,000
# 3     Chennai Super Kings    20,00,000
# 4     Chennai Super Kings    60,00,000
# ..                    ...           ...
# ...

# %%
df.head()
# Out:
#    Season             Name Nationality          Type                  Team  \
# 0    2023  Ajinkya Rahane      Indian        Batter    Chennai Super Kings
# 1    2023   Bhagath Varma      Indian   All-Rounder    Chennai Super Kings
# 2    2023   Kyle Jamieson    Overseas        Bowler    Chennai Super Kings
# 3    2023     Ajay Mandal      Indian   All-Rounder    Chennai Super Kings
# 4    2023  Nishant Sindhu      Indian   All-Rounder    Chennai Super Kings
#
#           Price
# 0    50,00,000
# 1    20,00,000
# 2  1,00,00,000
# 3    20,00,000
# 4    60,00,000

# %%
df.describe()
# Out:
#             Season
# count   284.000000
# mean   2022.281690
# std       0.450617
# min    2022.000000
# 25%    2022.000000
# 50%    2022.000000
# 75%    2023.000000
# max    2023.000000

# %%
null_values=df.isnull().sum()
print("null valuesin the data frame:")
print(null_values)
# Out:
# null valuesin the data frame:
# Season         0
# Name           0
# Nationality    0
# Type           0
# Team           0
# Price          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284 entries, 0 to 283
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Season       284 non-null    int64
#  1   Name         284 non-null    object
#  2   Nationality  284 non-null    object
#  3   Type         284 non-null    object
#  4   Team         284 non-null    object
#  5   Price        284 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 13.4+ KB

# %%
df['Nationality'].unique()
print(df['Nationality'].unique())
df['Nationality'].nunique()
# Out:
# ['Indian ' 'Overseas ']
# 2

# %%
df['Team'].unique()
print(df['Team'].unique())
df['Team'].nunique()
# Out:
# [' Chennai Super Kings' ' Delhi Capitals' ' Gujarat Titans'
#  ' Kolkata Knight Riders' ' Lucknow Super Giants' ' Mumbai Indians'
#  ' Punjab Kings' ' Rajasthan Royals' ' Royal Challengers Bangalore'
#  ' Sunrisers Hyderabad']
# 10

# %%
df.tail()
# Out:
#      Season               Name Nationality          Type  \
# 279    2022  Fazalhaq Farooqi    Overseas        Bowler
# 280    2022       Sean Abbott    Overseas        Bowler
# 281    2022         R Samarth      Indian       Batsman
# 282    2022    Shashank Singh      Indian   All-Rounder
# 283    2022     Saurabh Dubey      Indian        Bowler
#
#                      Team         Price
# 279   Sunrisers Hyderabad    50,00,000
# 280   Sunrisers Hyderabad  2,40,00,000
# 281   Sunrisers Hyderabad    20,00,000
# 282   Sunrisers Hyderabad    20,00,000
# 283   Sunrisers Hyderabad    20,00,000

# %%
df.groupby('Nationality').mean()
# Out:
# <ipython-input-14-3912a2c92b40>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Nationality').mean()
#                   Season
# Nationality
# Indian       2022.271277
# Overseas     2022.302083

# %%
df.sort_values('Price',ascending=False)
# Out:
#      Season             Name Nationality            Type  \
# 254    2022  Mahipal Lomror      Indian     All-Rounder
# 168    2022      K. Gowtham      Indian     All-Rounder
# 22     2023   N. Jagadeesan      Indian   Wicket-Keeper
# 202    2022   Kagiso Rabada    Overseas          Bowler
# 206    2022   Shahrukh Khan      Indian     All-Rounder
# ..      ...              ...         ...             ...
# 149    2022  Ajinkya Rahane      Indian         Batsman
# 93     2022    Devon Conway    Overseas         Batsman
# 70     2023    Akeal Hosein    Overseas          Bowler
# 2      2023   Kyle Jamieson    Overseas          Bowler
# 57     2023        Joe Root    Overseas          Batter
#
#                              Team         Price
# 254   Royal Challengers Bangalore    95,00,000
# 168          Lucknow Super Giants    90,00,000
# 22          Kolkata Knight Riders    90,00,000
# 202                  Punjab Kings  9,25,00,000
# 206                  Punjab Kings  9,00,00,000
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have already loaded your data into 'df'

# Calculate statistics
mean = df['Price'].mean()
median = df['Price'].median()
mode = df['Price'].mode().values[0]
std_dev = df['Price'].std()

print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Mode: {mode}")
print(f"Standard Deviation: {std_dev}")

# Create visualizations
plt.figure(figsize=(22, 6))
sns.countplot(x='Price', data=df, color='red')
plt.title("The Price")
plt.xlabel("Price Scores")
plt.ylabel("Count")
plt.show()

plt.figure(figsize=(10, 6))
plt.hist(df['Price'], bins=4, color='red', edgecolor='black')
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()
# Out:
# Mean: 25306338.028169014
# Median: 7500000.0
# Mode: 2000000.0
# Standard Deviation: 35450575.18915912

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(20, 30))
sns.swarmplot(x='Team', y='Name', data=df, palette=['yellow',
'black', 'orange', 'blue',
'skyblue','red','purple','brown','pink','green'])
plt.title("Number of Players in Each Team")
plt.xlabel("Team")
plt.ylabel("Number of Players")
plt.legend()
plt.show()
# Out:
# <ipython-input-28-642ca025a597>:4: FutureWarning: Passing `palette` without assigning `hue` is deprecated.
#   sns.swarmplot(x='Team', y='Name', data=df, palette=['yellow',
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Assuming you have already loaded your data into 'df'
# Define a custom color palette as a dictionary
team_specific_palette = {
'Team1': 'red',
'Team2': 'green',
'Team3': 'orange',
'Team4': 'blue',
'Team5': 'skyblue'
}
fig = plt.figure(figsize=(20, 6))
players_per_team = df.groupby('Team')['Name'].count().reset_index().sort_values(by='Name', ascending=True)
ax = sns.barplot(y='Team', x='Name', data=players_per_team,
palette=team_specific_palette.values())
for container in ax.containers:ax.bar_label(container, fmt='%d', label_type='edge',fontsize=12, color='black', padding=3, weight='bold')
plt.title('Number of Players in Each Team', fontsize=16)
plt.xlabel('Number of Players', fontsize=14)
plt.ylabel('Team', fontsize=14)
plt.show()

# %%
fig = plt.figure(figsize=(15, 8))
ax = sns.boxplot(x='Team', y='Price', data=df, )
plt.title('Price Distribution of Players in Each Team',
fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylabel('Price (US$)', fontsize=14)
plt.xlabel('Team', fontsize=14)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming you have already loaded your data into 'df'

# Clean the 'Team' column to remove leading and trailing whitespaces
df['Team'] = df['Team'].str.strip()

# Define a custom color palette as a dictionary with team names exactly as they appear in your dataset
team_specific_palette = {
    'Royal Challengers Bangalore': 'red',
    'Gujarat Titans': 'green',
    'Delhi Capitals': 'orange',
    'Mumbai Indians': 'blue',
    'Chennai Super Kings': 'yellow',
    'Lucknow Super Giants': 'black',
    'Rajasthan Royals': 'skyblue',
    'Kolkata Knight Riders': 'purple',
    'Punjab Kings': 'brown',
    'Sunrisers Hyderabad': 'pink'
}

# Calculate money spent by each team in millions of US dollars
money_spent_by_each_team = df.groupby('Team')['Price'].sum() / 1_000_000

# Create a new DataFrame for money spent by each team
money_spent_by_each_team_df = money_spent_by_each_team.reset_index().sort_values(by='Price', ascending=True)

# Create a violinplot
ax = sns.violinplot(x='Price', y='Team', data=df, palette=team_specific_palette, inner="quartile")
plt.title('Distribution of Money spent by each team (US$)', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.xlabel('Money spent (Million US$)', fontsize=14)
plt.ylabel('Team', fontsize=14)
plt.show()

# %%
fig = plt.figure(figsize=(20, 6))
ax = sns.boxplot(x='Nationality', y='Price', data=df)
plt.title('Price Distribution of Players from different Nationality', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylabel('Price (US$)', fontsize=14)
plt.xlabel('National Side', fontsize=14)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
mean_prices = df.groupby('Nationality')['Price'].mean().reset_index()
# Create a line plot
plt.figure(figsize=(12, 6))
sns.lineplot(x='Nationality', y='Price', data=mean_prices,marker='o', color='b')
plt.title('Mean Price (US$) of Players from Different Nationality', fontsize=16)
plt.xticks(rotation=45)
plt.xlabel('National Side', fontsize=14)
plt.ylabel('Mean Price (US$)', fontsize=14)
plt.grid(True)
plt.show()

# %%
fig = plt.figure(figsize=(15, 6))
df['Price Label'] =df['Price'].apply(lambda x: f'${x}')
top_5_players_by_price =df.sort_values(by='Price',ascending=False).head(5)
ax = sns.barplot(y='Name', x='Price',data=top_5_players_by_price.sort_values(by='Price',ascending=True))
for container in ax.containers:ax.bar_label(container, fmt='%d', label_type='edge',fontsize=12, color='black', padding=3, weight='bold',labels=top_5_players_by_price.sort_values(by='Price',ascending=True)
['Price Label'])
plt.title('Top 5 Players based on Price (US$)', fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.ylabel('')
plt.xlabel('Money Spent (in US$)', fontsize=14)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Assuming you have already loaded your data into 'df'
# Calculate the count of players for each team
team_counts = df['Team'].value_counts()
# Extract the team names and counts
teams = team_counts.index
player_counts = team_counts.values
# Create a pie chart to visualize the distribution of players among teams
plt.figure(figsize=(8, 8))
plt.pie(player_counts, labels=teams, autopct='%1.1f%%',
startangle=140)
plt.title('Distribution of Players Among Teams',
fontsize=16)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Assuming you have already loaded your data into 'df'
# Create a KDE plot for the 'Price' column
plt.figure(figsize=(8, 6))
sns.kdeplot(df['Price'], shade=True, color='blue')
plt.title(' Plot for Price IPL', fontsize=16)
plt.xlabel('Price', fontsize=14)
plt.ylabel('Density', fontsize=14)
plt.show()
# Out:
# <ipython-input-56-20421dc60022>:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Price'], shade=True, color='blue')
